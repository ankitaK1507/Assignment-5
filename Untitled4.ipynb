# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitaK1507/Assignment-5/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calculate length of string
a= "ankita"
length = len(a)
print("length of a:",length )

#make string from 1st two characters and last two characters from given string
a= "lower"
b= " upper"

c= a[2] +b[-2]
print(" new string:",c)

# to concatenate two strings
a ="hello"
b ="world"

c= a+b
print("concatenate:",c)
# Out:
# length of a: 6
#  new string: we
# concatenate: helloworld
